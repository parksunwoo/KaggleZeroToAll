# %%
Ordinal Regression ( also known as Ordinal Logistic Regression) is another extension of binomial logistics regression. Ordinal regression is used to predict the dependent variable with ‘ordered’ multiple categories and independent variables. In other words, it is used to facilitate the interaction of dependent variables (having multiple ordered levels) with one or more independent variables.

# %%
library(dplyr)
library(package = feather)
library(pscl)
library(MASS)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Classes and Methods for R developed in the
# Political Science Computational Laboratory
# Department of Political Science
# Stanford University
# Simon Jackman
# hurdle and zeroinfl functions by Achim Zeileis
#
# Attaching package: ‘MASS’
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %%
df <- read_feather('merged_data.feather')
# Out:
# Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”Warning message:
# “Coercing int64 to double”

# %%
# Description을 제외하고 필터링
df_trim = dplyr::select(df, -Description, -PetID, -RescuerID, -Name)
# is_train이 True인 데이터 열만 추려냅니다.
df_trim = dplyr::filter(df_trim, is_train)
# 각각의 컬럼을 categorical 형으로 바꾸줍니다.
df_trim$Dewormed = as.factor(df_trim$Dewormed)
df_trim$Gender = as.factor(df_trim$Gender)
df_trim$Vaccinated = as.factor(df_trim$Vaccinated)
df_trim$Sterilized = as.factor(df_trim$Sterilized)
df_trim$Type = as.factor(df_trim$Type)
df_trim$VideoAmt = as.factor(df_trim$VideoAmt)
df_trim$ColorName1 = as.factor(df_trim$ColorName1)
df_trim$ColorName2 = as.factor(df_trim$ColorName2)
df_trim$ColorName3 = as.factor(df_trim$ColorName3)
df_trim$BreedName1 = as.factor(df_trim$BreedName1)
df_trim$BreedName2 = as.factor(df_trim$BreedName2)
df_trim$StateName = as.factor(df_trim$StateName)

# %%
# Health와 MaturitySize는 ordinal value이기때문에 그에 맞게 변환해줍니다.
df_trim$Health <- ordered(df_trim$Health, levels = 1:3,
                              labels = c("Good", "Soso", "Bad"))

df_trim$MaturitySize <- ordered(df_trim$MaturitySize, levels = 1:4,
                              labels = c("Small", "Medium", "Large", "Very large"))

# %%
df_trim$Fee_free <- df_trim$Fee == 0

# %%
df_trim$AdoptionSpeed <- as.ordered(df_trim$AdoptionSpeed)

# %%
head(df_trim)
# Out:
#   AdoptionSpeed Age Dewormed Fee FurLength Gender Health MaturitySize PhotoAmt
# 1 2             3   No       100 1         Male   Good   Small        1
# 2 0             1   Not Sure   0 2         Male   Good   Medium       2
# 3 3             1   Yes        0 2         Male   Good   Medium       7
# 4 2             4   Yes      150 1         Female Good   Medium       8
# 5 2             1   No         0 1         Male   Good   Medium       3
# 6 2             3   No         0 1         Female Good   Medium       2
#   Quantity ⋯ Vaccinated VideoAmt is_train ColorName1 ColorName2 ColorName3
# 1 1        ⋯ No         0        TRUE     Black      White      NA
# 2 1        ⋯ Not Sure   0        TRUE     Black      Brown      NA
# 3 1        ⋯ Yes        0        TRUE     Brown      White      NA
# 4 1        ⋯ Yes        0        TRUE     Black      Brown      NA
# 5 1        ⋯ No         0        TRUE     Black      NA         NA
# 6 1        ⋯ No         0        TRUE     Cream      Gray       NA
#   BreedName1           BreedName2 StateName    Fee_free
# 1 Tabby                NA         Selangor     FALSE
# 2 Domestic Medium Hair NA         Kuala Lumpur  TRUE
# 3 Mixed Breed          NA         Selangor      TRUE
# 4 Mixed Breed          NA         Kuala Lumpur FALSE
# 5 Mixed Breed          NA         Selangor      TRUE
# 6 Domestic Short Hair  NA         Selangor      TRUE

# %%
model1 <- polr(AdoptionSpeed ~ Age, data = df_trim, Hess=TRUE)

# %%
summary(model1)
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ Age, data = df_trim, Hess = TRUE)
#
# Coefficients:
#       Value Std. Error t value
# Age 0.01055  0.0008457   12.48
#
# Intercepts:
#     Value    Std. Error t value
# 0|1  -3.4776   0.0506   -68.7466
# 1|2  -1.0915   0.0207   -52.6301
# 2|3   0.1159   0.0183     6.3148
# 3|4   1.0591   0.0204    51.8569
#
# Residual Deviance: 43776.85
# AIC: 43786.85

# %%
ctable <-coef(summary(model1))
p <- pnorm(abs(ctable[, "t value"]), lower.tail=FALSE) *2

# %%
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
#     Value      Std. Error   t value    p value
# Age  0.0105532 0.0008457408  12.478059 9.835463e-36
# 0|1 -3.4775805 0.0505855205 -68.746559 0.000000e+00
# 1|2 -1.0915089 0.0207392659 -52.630062 0.000000e+00
# 2|3  0.1158640 0.0183480908   6.314774 2.705569e-10
# 3|4  1.0591175 0.0204238517  51.856891 0.000000e+00

# %%
belta_age = 10

# %%
y = 0.01055 * belta_age

# %%
p1 = 1 / (1 + exp(-(-3.4776 - y)))
p12 = 1 / (1 + exp(-(-1.0915 - y)))
p23 = 1 / (1 + exp(-(0.1159 - y)))
p34 = 1 / (1 + exp(-(1.0591 - y)))

# %%
p2 = p12 - p1
p3 = p23 - p12
p4 = p34 - p23
p5 = 1- p34

# %%
c(p1, p2, p3, p4, p5) # belta_age = 20
# Out:
# [1] 0.02439689 0.18934768 0.26249833 0.22392552 0.29983158

# %%
c(p1, p2, p3, p4, p5) # belta_age = 10
# Out:
# [1] 0.02703805 0.20497128 0.27059065 0.21923861 0.27816141

# %%
model2 <- polr(AdoptionSpeed ~ MaturitySize + Type + Fee_free, data = df_trim, Hess=TRUE)

# %%
summary(model2)
ctable <- coef(summary(model2))
p <- pnorm(abs(ctable[, "t value"]), lower.tail = FALSE) * 2
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ MaturitySize + Type + Fee_free,
#     data = df_trim, Hess = TRUE)
#
# Coefficients:
#                   Value Std. Error t value
# MaturitySize.L -0.29004    0.20295 -1.4291
# MaturitySize.Q -0.35361    0.15332 -2.3063
# MaturitySize.C  0.04233    0.07675  0.5515
# TypeDog         0.28811    0.03009  9.5736
# Fee_freeTRUE   -0.11614    0.04075 -2.8501
#
# Intercepts:
#     Value    Std. Error t value
# 0|1  -3.3382   0.0975   -34.2421
# 1|2  -0.9432   0.0861   -10.9594
# 2|3   0.2694   0.0857     3.1432
# 3|4   1.2101   0.0862    14.0333
#
# Residual Deviance: 43751.32
# AIC: 43769.32
#                Value       Std. Error t value     p value
# MaturitySize.L -0.29003883 0.20295220  -1.4290992  1.529757e-01
# MaturitySize.Q -0.35360970 0.15332012  -2.3063490  2.109114e-02
# MaturitySize.C  0.04232535 0.07675111   0.5514624  5.813168e-01
# TypeDog         0.28811483 0.03009464   9.5736271  1.032195e-21
# Fee_freeTRUE   -0.11613777 0.04074934  -2.8500528  4.371197e-03
# 0|1            -3.33818490 0.09748787 -34.2420552 5.726468e-257
# 1|2            -0.94324774 0.08606749 -10.9593962  5.989763e-28
# 2|3             0.26938860 0.08570405   3.1432424  1.670874e-03
# 3|4             1.21011864 0.08623217  14.0332615  9.755963e-45

# %%
model3 <- polr(AdoptionSpeed ~ MaturitySize + Type + Fee_free + MaturitySize:Fee_free, data=df_trim, Hess=TRUE)

# %%
summary(model3)
ctable <- coef(summary(model3))
p <- pnorm(abs(ctable[, "t value"]), lower.tail = FALSE) * 2
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ MaturitySize + Type + Fee_free +
#     MaturitySize:Fee_free, data = df_trim, Hess = TRUE)
#
# Coefficients:
#                                Value Std. Error t value
# MaturitySize.L              -0.46457    0.48960 -0.9489
# MaturitySize.Q              -0.31439    0.36912 -0.8517
# MaturitySize.C               0.11282    0.18112  0.6229
# TypeDog                      0.28586    0.03023  9.4562
# Fee_freeTRUE                -0.04256    0.20284 -0.2098
# MaturitySize.L:Fee_freeTRUE  0.21310    0.53776  0.3963
# MaturitySize.Q:Fee_freeTRUE -0.05341    0.40571 -0.1317
# MaturitySize.C:Fee_freeTRUE -0.09403    0.19995 -0.4703
#
# Intercepts:
#     Value    Std. Error t value
# 0|1  -3.2822   0.1912   -17.1645
# 1|2  -0.8871   0.1857    -4.7772
# 2|3   0.3258   0.1856     1.7556
# 3|4   1.2667   0.1858     6.8160
#
# Residual Deviance: 43747.57
# AIC: 43771.57
#                             Value       Std. Error t value     p value
# MaturitySize.L              -0.46457193 0.48959732  -0.9488858 3.426787e-01
# MaturitySize.Q              -0.31439429 0.36912373  -0.8517315 3.943632e-01
# MaturitySize.C               0.11282068 0.18111706   0.6229158 5.333399e-01
# TypeDog                      0.28586454 0.03023032   9.4562194 3.192785e-21
# Fee_freeTRUE                -0.04256437 0.20283707  -0.2098451 8.337886e-01
# MaturitySize.L:Fee_freeTRUE  0.21310134 0.53776199   0.3962744 6.919026e-01
# MaturitySize.Q:Fee_freeTRUE -0.05341253 0.40571353  -0.1316509 8.952605e-01
# MaturitySize.C:Fee_freeTRUE -0.09403073 0.19995433  -0.4702610 6.381685e-01
# 0|1                         -3.28219867 0.19122022 -17.1644955 4.897201e-66
# 1|2                         -0.88707839 0.18568947  -4.7772144 1.777403e-06
# 2|3                          0.32580920 0.18558124   1.7556150 7.915418e-02
# 3|4                          1.26672090 0.18584622   6.8159628 9.363451e-12

# %%
model4 <- polr(AdoptionSpeed ~ Gender + Sterilized + Type, data = df_trim, Hess=TRUE)

# %%
summary(model4)
ctable <- coef(summary(model4))
p <- pnorm(abs(ctable[, "t value"]), lower.tail = FALSE) * 2
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ Gender + Sterilized + Type, data = df_trim,
#     Hess = TRUE)
#
# Coefficients:
#                      Value Std. Error t value
# GenderMale         -0.1915    0.03210  -5.964
# GenderMixed         0.1974    0.04472   4.414
# SterilizedNot Sure  0.5822    0.04833  12.047
# SterilizedYes       0.8632    0.03809  22.661
# TypeDog             0.2894    0.02986   9.693
#
# Intercepts:
#     Value    Std. Error t value
# 0|1  -3.2850   0.0555   -59.2219
# 1|2  -0.8775   0.0312   -28.1240
# 2|3   0.3640   0.0303    12.0200
# 3|4   1.3396   0.0322    41.6658
#
# Residual Deviance: 43165.48
# AIC: 43183.48
#                    Value      Std. Error t value    p value
# GenderMale         -0.1914758 0.03210365  -5.964300  2.456849e-09
# GenderMixed         0.1974077 0.04472340   4.413969  1.014925e-05
# SterilizedNot Sure  0.5821836 0.04832520  12.047205  2.006374e-33
# SterilizedYes       0.8632177 0.03809268  22.660985 1.087223e-113
# TypeDog             0.2893794 0.02985589   9.692539  3.243628e-22
# 0|1                -3.2850448 0.05547006 -59.221947  0.000000e+00
# 1|2                -0.8774937 0.03120085 -28.124037 4.979921e-174
# 2|3                 0.3640102 0.03028375  12.019983  2.790285e-33
# 3|4                 1.3396135 0.03215139  41.665808  0.000000e+00

# %%
model5 <- polr(AdoptionSpeed ~ Sterilized + Type + Sterilized:Type, data = df_trim, Hess=TRUE)

# %%
summary(model5)
ctable <- coef(summary(model5))
p <- pnorm(abs(ctable[, "t value"]), lower.tail = FALSE) * 2
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ Sterilized + Type + Sterilized:Type,
#     data = df_trim, Hess = TRUE)
#
# Coefficients:
#                              Value Std. Error t value
# SterilizedNot Sure          0.5133    0.07734   6.637
# SterilizedYes               0.9335    0.05842  15.980
# TypeDog                     0.2931    0.03531   8.299
# SterilizedNot Sure:TypeDog  0.1082    0.09885   1.095
# SterilizedYes:TypeDog      -0.1518    0.07587  -2.001
#
# Intercepts:
#     Value    Std. Error t value
# 0|1  -3.2379   0.0534   -60.6059
# 1|2  -0.8332   0.0277   -30.1200
# 2|3   0.4037   0.0269    15.0184
# 3|4   1.3754   0.0290    47.4094
#
# Residual Deviance: 43239.50
# AIC: 43257.50
#                            Value      Std. Error t value    p value
# SterilizedNot Sure          0.5133009 0.07734026   6.636917  3.203129e-11
# SterilizedYes               0.9334567 0.05841546  15.979616  1.772338e-57
# TypeDog                     0.2930830 0.03531419   8.299300  1.047269e-16
# SterilizedNot Sure:TypeDog  0.1082439 0.09885414   1.094986  2.735230e-01
# SterilizedYes:TypeDog      -0.1518280 0.07587213  -2.001103  4.538124e-02
# 0|1                        -3.2379195 0.05342578 -60.605932  0.000000e+00
# 1|2                        -0.8331554 0.02766118 -30.120017 2.650197e-199
# 2|3                         0.4036601 0.02687761  15.018450  5.559264e-51
# 3|4                         1.3753874 0.02901088  47.409365  0.000000e+00

# %%
model6 <- polr(AdoptionSpeed ~ Sterilized + Type + Gender + Sterilized:Type + Sterilized:Gender + Type:Gender, data = df_trim, Hess=TRUE)

# %%
summary(model6)
ctable <- coef(summary(model6))
p <- pnorm(abs(ctable[, "t value"]), lower.tail = FALSE) * 2
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ Sterilized + Type + Gender + Sterilized:Type +
#     Sterilized:Gender + Type:Gender, data = df_trim, Hess = TRUE)
#
# Coefficients:
#                                   Value Std. Error t value
# SterilizedNot Sure              0.43066    0.09493  4.5365
# SterilizedYes                   0.96413    0.06967 13.8390
# TypeDog                         0.37306    0.04807  7.7614
# GenderMale                     -0.09879    0.05254 -1.8801
# GenderMixed                     0.17742    0.06458  2.7473
# SterilizedNot Sure:TypeDog      0.13233    0.09942  1.3310
# SterilizedYes:TypeDog          -0.16812    0.07695 -2.1849
# SterilizedNot Sure:GenderMale   0.04270    0.10611  0.4024
# SterilizedYes:GenderMale       -0.01935    0.07990 -0.2422
# SterilizedNot Sure:GenderMixed  0.31968    0.13931  2.2947
# SterilizedYes:GenderMixed       0.03464    0.15311  0.2263
# TypeDog:GenderMale             -0.16690    0.06491 -2.5711
# TypeDog:GenderMixed            -0.01763    0.09067 -0.1945
#
# Intercepts:
#     Value    Std. Error t value
# 0|1  -3.2452   0.0603   -53.7788
# 1|2  -0.8369   0.0393   -21.2815
# 2|3   0.4058   0.0387    10.4795
# 3|4   1.3823   0.0403    34.3326
#
# Residual Deviance: 43145.34
# AIC: 43179.34
#                                Value       Std. Error t value     p value
# SterilizedNot Sure              0.43065964 0.09493117   4.5365463  5.718293e-06
# SterilizedYes                   0.96413202 0.06966752  13.8390470  1.481578e-43
# TypeDog                         0.37305776 0.04806581   7.7613956  8.399987e-15
# GenderMale                     -0.09879204 0.05254480  -1.8801488  6.008780e-02
# GenderMixed                     0.17742332 0.06458066   2.7473134  6.008569e-03
# SterilizedNot Sure:TypeDog      0.13233320 0.09942182   1.3310277  1.831799e-01
# SterilizedYes:TypeDog          -0.16811790 0.07694507  -2.1849081  2.889559e-02
# SterilizedNot Sure:GenderMale   0.04270172 0.10610777   0.4024372  6.873623e-01
# SterilizedYes:GenderMale       -0.01935089 0.07989857  -0.2421932  8.086304e-01
# SterilizedNot Sure:GenderMixed  0.31967671 0.13931340   2.2946586  2.175269e-02
# SterilizedYes:GenderMixed       0.03464417 0.15310678   0.2262746  8.209879e-01
# TypeDog:GenderMale             -0.16690253 0.06491442  -2.5711163  1.013713e-02
# TypeDog:GenderMixed            -0.01763389 0.09067243  -0.1944790  8.458008e-01
# 0|1                            -3.24523381 0.06034408 -53.7788255  0.000000e+00
# 1|2                            -0.83685182 0.03932306 -21.2814504 1.686443e-100
# 2|3                             0.40577621 0.03872092  10.4795094  1.072989e-25
# 3|4                             1.38228021 0.04026149  34.3325654 2.564336e-258

# %%
model7 <- polr(AdoptionSpeed ~ StateName + BreedName1 + FurLength + Sterilized + Type + Gender + Fee_free + MaturitySize + PhotoAmt + Vaccinated + VideoAmt + Health, data = df_trim %>% dplyr::filter(is_train) %>% dplyr::select(-is_train), Hess=TRUE)
# Out:
# Warning message in polr(AdoptionSpeed ~ StateName + BreedName1 + FurLength + Sterilized + :
# “design appears to be rank-deficient, so dropping some coefs”

# %%
summary(model7)
ctable <- coef(summary(model7))
p <- pnorm(abs(ctable[, "t value"]), lower.tail = FALSE) * 2
ctable <- cbind(ctable, "p value" = p)
ctable
# Out:
# Call:
# polr(formula = AdoptionSpeed ~ StateName + BreedName1 + FurLength +
#     Sterilized + Type + Gender + Fee_free + MaturitySize + PhotoAmt +
#     Vaccinated + VideoAmt + Health, data = df_trim %>% dplyr::filter(is_train) %>%
#     dplyr::select(-is_train), Hess = TRUE)
#
# Coefficients:
#                                                              Value Std. Error
# StateNameKedah                                            0.817773  1.910e-01
# StateNameKelantan                                         0.316012  5.284e-01
# StateNameKuala Lumpur                                     0.328446  8.764e-02
# StateNameLabuan                                           1.231552  9.678e-01
# StateNameMelaka                                           1.197249  1.930e-01
# StateNameNegeri Sembilan                                  0.732248  1.442e-01
# StateNamePahang                                           0.018611  2.325e-01
# StateNamePerak                                            0.577114  1.214e-01
# StateNamePulau Pinang                                     0.579482  1.038e-01
# StateNameSabah                                            0.334521  4.577e-01
# StateNameSarawak                                          2.294519  6.266e-01
# StateNameSelangor                                         0.163294  8.466e-02
# StateNameTerengganu                                       0.629472  3.843e-01
# BreedName1Affenpinscher                                  13.592591  3.412e-05
# BreedName1Airedale Terrier                               14.673024  1.343e-05
# BreedName1Akita                                          -0.507443  1.528e+00
# BreedName1American Bulldog                               13.031454  1.265e-05
# BreedName1American Curl                                   0.091090  5.492e-01
# BreedName1American Shorthair                              0.083803  3.986e-01
# BreedName1American Staffordshire Terrier                 -0.307711  9.348e-01
# BreedName1American Water Spaniel                         14.512325  2.492e-05
# BreedName1American Wirehair                              -0.149224  8.121e-01
# BreedName1Applehead Siamese                              -0.089671  1.358e+00
# BreedName1Australian Kelpie                               0.172235  7.495e-01
# BreedName1Australian Shepherd                            13.307841  9.246e-06
# BreedName1Australian Terrier                              0.675798  7.921e-01
# BreedName1Balinese                                        0.927892  1.003e+00
# BreedName1Basenji                                         0.507133  7.597e-01
# BreedName1Basset Hound                                   -1.132094  6.969e-01
# BreedName1Beagle                                         -0.984416  3.956e-01
# BreedName1Bedlington Terrier                             -1.985527  1.533e+00
# BreedName1Belgian Shepherd Dog Sheepdog                  -1.357424  1.241e+00
# BreedName1Belgian Shepherd Laekenois                     -2.413551  1.732e+00
# BreedName1Belgian Shepherd Malinois                      -0.754198  4.975e-01
# BreedName1Bengal                                         -0.758000  4.082e-01
# BreedName1Birman                                          0.627913  1.313e+00
# BreedName1Black Labrador Retriever                       -0.136286  6.757e-01
# BreedName1Black Mouth Cur                                -0.430551  9.366e-01
# BreedName1Bobtail                                         0.553375  5.573e-01
# BreedName1Bombay                                          0.719514  6.110e-01
# BreedName1Border Collie                                  -0.508391  4.842e-01
# BreedName1Boston Terrier                                 -0.683931  8.217e-01
# BreedName1Boxer                                          -0.058937  6.650e-01
# BreedName1British Shorthair                              -0.914645  4.622e-01
# BreedName1Bull Terrier                                   -0.346976  5.702e-01
# BreedName1Bullmastiff                                    -0.228110  6.158e-01
# BreedName1Silky Terrier                                  -1.420402  5.213e-01
# BreedName1Silver                                         13.610286  5.223e-05
# BreedName1Singapura                                       0.919073  6.387e-01
# BreedName1Snowshoe                                        1.664191  1.165e+00
# BreedName1Somali                                         -0.994371  8.743e-01
# BreedName1Spaniel                                        13.272105  1.124e-05
# BreedName1Sphynx (hairless cat)                         -16.895060  1.465e-05
# BreedName1Spitz                                          -0.080810  3.910e-01
# BreedName1Staffordshire Bull Terrier                     13.448165  1.122e-05
# BreedName1Standard Poodle                                 0.316926  1.128e+00
# BreedName1Swedish Vallhund                               14.159265  7.883e-06
# BreedName1Tabby                                          -0.225273  3.571e-01
# BreedName1Terrier                                        -0.153904  3.693e-01
# BreedName1Tiger                                          -0.294450  5.310e-01
# BreedName1Tonkinese                                      -2.114138  8.418e-01
# BreedName1Torbie                                         -1.974568  1.530e+00
# BreedName1Tortoiseshell                                  -0.376841  4.397e-01
# BreedName1Toy Fox Terrier                                -0.436589  1.005e+00
# BreedName1Turkish Angora                                  0.498361  7.730e-01
# BreedName1Turkish Van                                     0.593618  7.422e-01
# BreedName1Tuxedo                                         -0.161317  4.262e-01
# BreedName1Weimaraner                                      1.896633  1.220e+00
# BreedName1Welsh Corgi                                    -1.744944  1.595e+00
# BreedName1West Highland White Terrier Westie             -0.443609  7.322e-01
# BreedName1Wheaten Terrier                                 0.279210  1.115e+00
# BreedName1Whippet                                        -1.246252  1.533e+00
# BreedName1White German Shepherd                          -0.257273  1.100e+00
# BreedName1Wirehaired Terrier                              0.439301  1.314e+00
# BreedName1Yellow Labrador Retriever                       0.311625  5.561e-01
# BreedName1Yorkshire Terrier Yorkie                       -1.840574  8.580e-01
# FurLength                                                -0.129929  3.174e-02
# SterilizedNot Sure                                        0.535556  5.827e-02
# SterilizedYes                                             0.859223  4.298e-02
# GenderMale                                               -0.154552  3.297e-02
# GenderMixed                                               0.256689  4.650e-02
# Fee_freeTRUE                                             -0.283782  4.368e-02
# MaturitySize.L                                            0.011086  2.182e-01
# MaturitySize.Q                                           -0.113890  1.628e-01
# MaturitySize.C                                            0.054030  8.083e-02
# PhotoAmt                                                 -0.015844  4.292e-03
# VaccinatedNot Sure                                        0.275673  5.855e-02
# VaccinatedYes                                             0.318633  3.744e-02
# VideoAmt1                                                -0.156450  8.868e-02
# VideoAmt2                                                -0.025649  1.829e-01
# VideoAmt3                                                -0.298490  2.982e-01
# VideoAmt4                                                 0.950420  4.693e-01
# VideoAmt5                                                 0.167951  6.323e-01
# VideoAmt6                                                 1.269010  1.032e+00
# VideoAmt7                                                -0.356289  1.493e+00
# VideoAmt8                                                 1.095378  1.253e+00
# Health.L                                                  0.556876  2.255e-01
# Health.Q                                                 -0.009749  1.477e-01
#                                                            t value
# StateNameKedah                                           4.281e+00
# StateNameKelantan                                        5.980e-01
# StateNameKuala Lumpur                                    3.748e+00
# StateNameLabuan                                          1.272e+00
# StateNameMelaka                                          6.202e+00
# StateNameNegeri Sembilan                                 5.077e+00
# StateNamePahang                                          8.005e-02
# StateNamePerak                                           4.755e+00
# StateNamePulau Pinang                                    5.584e+00
# StateNameSabah                                           7.309e-01
# StateNameSarawak                                         3.662e+00
# StateNameSelangor                                        1.929e+00
# StateNameTerengganu                                      1.638e+00
# BreedName1Affenpinscher                                  3.983e+05
# BreedName1Airedale Terrier                               1.093e+06
# BreedName1Akita                                         -3.320e-01
# BreedName1American Bulldog                               1.030e+06
# BreedName1American Curl                                  1.659e-01
# BreedName1American Shorthair                             2.102e-01
# BreedName1American Staffordshire Terrier                -3.292e-01
# BreedName1American Water Spaniel                         5.823e+05
# BreedName1American Wirehair                             -1.837e-01
# BreedName1Applehead Siamese                             -6.603e-02
# BreedName1Australian Kelpie                              2.298e-01
# BreedName1Australian Shepherd                            1.439e+06
# BreedName1Australian Terrier                             8.532e-01
# BreedName1Balinese                                       9.248e-01
# BreedName1Basenji                                        6.676e-01
# BreedName1Basset Hound                                  -1.625e+00
# BreedName1Beagle                                        -2.488e+00
# BreedName1Bedlington Terrier                            -1.295e+00
# BreedName1Belgian Shepherd Dog Sheepdog                 -1.093e+00
# BreedName1Belgian Shepherd Laekenois                    -1.394e+00
# BreedName1Belgian Shepherd Malinois                     -1.516e+00
# BreedName1Bengal                                        -1.857e+00
# BreedName1Birman                                         4.784e-01
# BreedName1Black Labrador Retriever                      -2.017e-01
# BreedName1Black Mouth Cur                               -4.597e-01
# BreedName1Bobtail                                        9.929e-01
# BreedName1Bombay                                         1.178e+00
# BreedName1Border Collie                                 -1.050e+00
# BreedName1Boston Terrier                                -8.323e-01
# BreedName1Boxer                                         -8.862e-02
# BreedName1British Shorthair                             -1.979e+00
# BreedName1Bull Terrier                                  -6.085e-01
# BreedName1Bullmastiff                                   -3.704e-01
# BreedName1Burmese                                       -1.328e+00
# BreedName1Burmilla                                       9.764e-01
# BreedName1Calico                                         1.253e-01
# BreedName1Cattle Dog                                     7.211e-01
# BreedName1Cavalier King Charles Spaniel                 -4.100e-01
# BreedName1Chartreux                                     -2.914e-02
# BreedName1Chausie                                        1.795e+06
# BreedName1Chihuahua                                     -1.653e+00
# BreedName1Chinese Crested Dog                           -1.259e+06
# BreedName1Chocolate Labrador Retriever                   4.174e-01
# BreedName1Chow Chow                                     -2.812e+00
# BreedName1Cocker Spaniel                                -2.061e+00
# BreedName1Collie                                        -2.419e+00
# BreedName1Coonhound                                      5.013e-01
# BreedName1Corgi                                         -1.808e+00
# BreedName1Cymric                                         9.796e-01
# BreedName1Dachshund                                     -2.080e+00
# BreedName1Dalmatian                                     -7.833e-01
# BreedName1Dilute Calico                                  7.481e-01
# BreedName1Dilute Tortoiseshell                           8.370e-01
# BreedName1Doberman Pinscher                             -1.461e+00
# BreedName1Domestic Long Hair                            -1.795e+00
# BreedName1Domestic Medium Hair                          -6.915e-01
# BreedName1Domestic Short Hair                           -3.316e-01
# BreedName1Dutch Shepherd                                -1.420e+00
# BreedName1Egyptian Mau                                  -8.852e-01
# BreedName1English Bulldog                               -1.348e+00
# BreedName1English Cocker Spaniel                        -2.265e+00
# BreedName1English Pointer                               -3.370e-01
# BreedName1English Springer Spaniel                       4.940e-01
# BreedName1Exotic Shorthair                              -4.760e-01
# BreedName1Extra-Toes Cat (Hemingway Polydactyl)         -1.205e+00
# BreedName1Field Spaniel                                  1.869e+06
# BreedName1Flat-coated Retriever                          8.916e-01
# BreedName1Fox Terrier                                   -8.003e-01
# BreedName1Foxhound                                      -1.854e+00
# BreedName1French Bulldog                                -1.424e+00
# BreedName1German Pinscher                               -4.934e-02
# BreedName1German Shepherd Dog                           -1.451e+00
# BreedName1German Spitz                                  -3.047e-01
# BreedName1Glen of Imaal Terrier                         -1.146e+00
# BreedName1Golden Retriever                              -2.478e+00
# BreedName1Great Dane                                    -2.279e+00
# BreedName1Greyhound                                     -1.405e-02
# BreedName1Havana                                         4.606e-01
# BreedName1Himalayan                                     -1.688e+00
# BreedName1Hound                                         -4.563e-01
# BreedName1Husky                                         -1.703e+00
# BreedName1Irish Setter                                  -1.246e-01
# BreedName1Irish Terrier                                  7.217e+05
# BreedName1Irish Wolfhound                               -8.916e-01
# BreedName1Jack Russell Terrier                          -7.407e-01
# BreedName1Jack Russell Terrier (Parson Russell Terrier) -6.612e-01
# BreedName1Japanese Bobtail                               3.609e-02
# BreedName1Japanese Chin                                 -3.228e-01
# BreedName1Javanese                                      -4.394e-01
# BreedName1Kai Dog                                        7.122e+05
# BreedName1Korat                                         -4.834e-02
# BreedName1Kuvasz                                        -1.627e+00
# BreedName1Labrador Retriever                            -1.587e+00
# BreedName1Lancashire Heeler                              4.716e-02
# BreedName1Lhasa Apso                                    -1.607e+00
# BreedName1Lowchen                                        4.716e-02
# BreedName1Maine Coon                                    -1.976e+00
# BreedName1Maltese                                       -3.076e+00
# BreedName1Manchester Terrier                            -1.068e+00
# BreedName1Manx                                           6.584e-02
# BreedName1Mastiff                                        1.091e+00
# BreedName1Miniature Pinscher                            -1.274e+00
# BreedName1Mixed Breed                                    6.197e-01
# BreedName1Mountain Dog                                   1.270e+06
# BreedName1Munsterlander                                 -3.466e-01
# BreedName1Nebelung                                       3.579e+05
# BreedName1Norwegian Forest Cat                          -2.697e+00
# BreedName1Ocicat                                        -1.962e+00
# BreedName1Old English Sheepdog                           9.046e-02
# BreedName1Oriental Long Hair                            -2.898e+00
# BreedName1Oriental Short Hair                            6.880e-01
# BreedName1Oriental Tabby                                 2.341e-01
# BreedName1Papillon                                      -1.848e+00
# BreedName1Pekingese                                     -2.431e+00
# BreedName1Persian                                       -2.802e+00
# BreedName1Pit Bull Terrier                              -7.015e-01
# BreedName1Pixie-Bob                                      1.191e+06
# BreedName1Pointer                                        1.227e+06
# BreedName1Pomeranian                                    -1.748e+00
# BreedName1Poodle                                        -3.285e+00
# BreedName1Pug                                           -2.660e+00
# BreedName1Ragamuffin                                    -1.184e+00
# BreedName1Ragdoll                                       -1.773e+00
# BreedName1Rat Terrier                                   -1.105e-01
# BreedName1Retriever                                      4.228e-01
# BreedName1Rhodesian Ridgeback                           -9.362e-01
# BreedName1Rottweiler                                    -2.410e+00
# BreedName1Russian Blue                                  -2.077e+00
# BreedName1Saint Bernard                                 -2.693e+00
# BreedName1Samoyed                                       -2.921e-01
# BreedName1Schnauzer                                     -2.470e+00
# BreedName1Scottish Fold                                 -1.212e+00
# BreedName1Scottish Terrier Scottie                      -1.174e+00
# BreedName1Setter                                        -1.561e-01
# BreedName1Shar Pei                                      -2.843e-01
# BreedName1Sheep Dog                                      1.405e+06
# BreedName1Shepherd                                       7.183e-02
# BreedName1Shetland Sheepdog Sheltie                     -9.962e-01
# BreedName1Shiba Inu                                     -2.783e-01
# BreedName1Shih Tzu                                      -3.060e+00
# BreedName1Siamese                                       -2.369e+00
# BreedName1Siberian                                      -1.255e+00
# BreedName1Siberian Husky                                -2.215e+00
# BreedName1Silky Terrier                                 -2.725e+00
# BreedName1Silver                                         2.606e+05
# BreedName1Singapura                                      1.439e+00
# BreedName1Snowshoe                                       1.429e+00
# BreedName1Somali                                        -1.137e+00
# BreedName1Spaniel                                        1.181e+06
# BreedName1Sphynx (hairless cat)                         -1.153e+06
# BreedName1Spitz                                         -2.067e-01
# BreedName1Staffordshire Bull Terrier                     1.199e+06
# BreedName1Standard Poodle                                2.810e-01
# BreedName1Swedish Vallhund                               1.796e+06
# BreedName1Tabby                                         -6.308e-01
# BreedName1Terrier                                       -4.168e-01
# BreedName1Tiger                                         -5.545e-01
# BreedName1Tonkinese                                     -2.511e+00
# BreedName1Torbie                                        -1.290e+00
# BreedName1Tortoiseshell                                 -8.570e-01
# BreedName1Toy Fox Terrier                               -4.344e-01
# BreedName1Turkish Angora                                 6.448e-01
# BreedName1Turkish Van                                    7.998e-01
# BreedName1Tuxedo                                        -3.785e-01
# BreedName1Weimaraner                                     1.554e+00
# BreedName1Welsh Corgi                                   -1.094e+00
# BreedName1West Highland White Terrier Westie            -6.059e-01
# BreedName1Wheaten Terrier                                2.504e-01
# BreedName1Whippet                                       -8.131e-01
# BreedName1White German Shepherd                         -2.338e-01
# BreedName1Wirehaired Terrier                             3.342e-01
# BreedName1Yellow Labrador Retriever                      5.604e-01
# BreedName1Yorkshire Terrier Yorkie                      -2.145e+00
# FurLength                                               -4.094e+00
# SterilizedNot Sure                                       9.191e+00
# SterilizedYes                                            1.999e+01
# GenderMale                                              -4.688e+00
# GenderMixed                                              5.520e+00
# Fee_freeTRUE                                            -6.497e+00
# MaturitySize.L                                           5.080e-02
# MaturitySize.Q                                          -6.997e-01
# MaturitySize.C                                           6.684e-01
# PhotoAmt                                                -3.691e+00
# VaccinatedNot Sure                                       4.708e+00
# VaccinatedYes                                            8.512e+00
# VideoAmt1                                               -1.764e+00
# VideoAmt2                                               -1.402e-01
# VideoAmt3                                               -1.001e+00
# VideoAmt4                                                2.025e+00
# VideoAmt5                                                2.656e-01
# VideoAmt6                                                1.229e+00
# VideoAmt7                                               -2.386e-01
# VideoAmt8                                                8.741e-01
# Health.L                                                 2.470e+00
# Health.Q                                                -6.598e-02
#
# Intercepts:
#     Value         Std. Error    t value
# 0|1       -4.0989        0.3875      -10.5769
# 1|2       -1.6166        0.3846       -4.2037
# 2|3       -0.3134        0.3843       -0.8156
# 3|4        0.7143        0.3844        1.8583
#
# Residual Deviance: 41942.88
# AIC: 42366.88
# (17 observations deleted due to missingness)
#                                          Value       Std. Error   t value
# StateNameKedah                            0.81777321 1.910075e-01  4.281366e+00
# StateNameKelantan                         0.31601152 5.284448e-01  5.980029e-01
# VideoAmt2                                -0.02564910 0.182901422   -0.14023455
# VideoAmt3                                -0.29849014 0.298225623   -1.00088697
# VideoAmt4                                 0.95042034 0.469296390    2.02520276
# VideoAmt5                                 0.16795066 0.632334699    0.26560406
# VideoAmt6                                 1.26900956 1.032183961    1.22944127
# VideoAmt7                                -0.35628853 1.493481190   -0.23856245
# VideoAmt8                                 1.09537843 1.253090539    0.87414149
# Health.L                                  0.55687574 0.225493341    2.46958842
# Health.Q                                 -0.00974854 0.147739292   -0.06598475
# 0|1                                      -4.09886935 0.387530078  -10.57690637
# 1|2                                      -1.61658005 0.384565490   -4.20365344
# 2|3                                      -0.31343463 0.384314738   -0.81556756
# 3|4                                       0.71427153 0.384370534    1.85828898
#                                          p value
# StateNameKedah                           1.857492e-05
# StateNameKelantan                        5.498380e-01
# StateNameKuala Lumpur                    1.784534e-04
# StateNameLabuan                          2.031978e-01
# StateNameMelaka                          5.583561e-10
# StateNameNegeri Sembilan                 3.828545e-07
# StateNamePahang                          9.361943e-01
# StateNamePerak                           1.982797e-06
# StateNamePulau Pinang                    2.346472e-08
# StateNameSabah                           4.648212e-01
# StateNameSarawak                         2.503661e-04
# StateNameSelangor                        5.375092e-02
# StateNameTerengganu                      1.013961e-01
# BreedName1Affenpinscher                  0.000000e+00
# BreedName1Airedale Terrier               0.000000e+00
# BreedName1Akita                          7.398531e-01
# BreedName1American Bulldog               0.000000e+00
# BreedName1American Curl                  8.682693e-01
# BreedName1American Shorthair             8.334869e-01
# BreedName1American Staffordshire Terrier 7.420129e-01
# BreedName1American Water Spaniel         0.000000e+00
# BreedName1American Wirehair              8.542150e-01
# BreedName1Applehead Siamese              9.473567e-01
# BreedName1Australian Kelpie              8.182464e-01
# BreedName1Australian Shepherd            0.000000e+00
# BreedName1Australian Terrier             3.935532e-01
# BreedName1Balinese                       3.550548e-01
# BreedName1Basenji                        5.043979e-01
# BreedName1Basset Hound                   1.042545e-01
# BreedName1Beagle                         1.283017e-02
# ⋮                                        ⋮
# BreedName1White German Shepherd          8.151232e-01
# BreedName1Wirehaired Terrier             7.382255e-01
# BreedName1Yellow Labrador Retriever      5.752018e-01
# BreedName1Yorkshire Terrier Yorkie       3.193709e-02
# FurLength                                4.243117e-05
# SterilizedNot Sure                       3.899491e-20
# SterilizedYes                            6.414897e-89
# GenderMale                               2.759153e-06
# GenderMixed                              3.383588e-08
# Fee_freeTRUE                             8.182390e-11
# MaturitySize.L                           9.594830e-01
# MaturitySize.Q                           4.841155e-01
# MaturitySize.C                           5.038583e-01
# PhotoAmt                                 2.230767e-04
# VaccinatedNot Sure                       2.495906e-06
# VaccinatedYes                            1.716303e-17
# VideoAmt1                                7.769924e-02
# VideoAmt2                                8.884747e-01
# VideoAmt3                                3.168815e-01
# VideoAmt4                                4.284655e-02
# VideoAmt5                                7.905442e-01
# VideoAmt6                                2.189064e-01
# VideoAmt7                                8.114449e-01
# VideoAmt8                                3.820412e-01
# Health.L                                 1.352686e-02
# Health.Q                                 9.473900e-01
# 0|1                                      3.813420e-26
# 1|2                                      2.626410e-05
# 2|3                                      4.147475e-01
# 3|4                                      6.312799e-02
